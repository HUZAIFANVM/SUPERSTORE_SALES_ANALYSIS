# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
pd.options.display.float_format='{: .3f}'.format

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('/storage/emulated/0/pydriod3')

# %%
df=pd.read_csv('superstore_dataset2011-2015.csv', encoding='ISO-8859-1')

# %%
df.head(5)
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
df.tail(5)
# Out:
#        Row ID        Order ID  Order Date Ship Date       Ship Mode  \
# 51285   32593  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name    Segment       City             State  \
# 51285    EB-13975        Erica Bern  Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis   Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton   Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen   Consumer     Juárez         Chihuahua
# 51289    JM-15580     Jill Matthias   Consumer   Loveland          Colorado
#
#        ...        Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.duplicated().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#           Row ID  Postal Code      Sales   Quantity   Discount     Profit  \
# count  51290.000     9994.000  51290.000  51290.000  51290.000  51290.000
# mean   25645.500    55190.379    246.491      3.477      0.143     28.611
# std    14806.292    32063.693    487.565      2.279      0.212    174.341
# min        1.000     1040.000      0.444      1.000      0.000  -6599.978
# 25%    12823.250    23223.000     30.759      2.000      0.000      0.000
# 50%    25645.500    56430.500     85.053      3.000      0.000      9.240
# 75%    38467.750    90008.000    251.053      5.000      0.200     36.810
# max    51290.000    99301.000  22638.480     14.000      0.850   8399.976
#
#        Shipping Cost
# count      51290.000
# mean          26.376
# std           57.297
# min            0.000
# 25%            2.610
# 50%            7.790
# 75%           24.450
# max          933.570

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df=df.drop(['Row ID','Order ID','Customer ID','Postal Code'],axis=1)

# %%
df_sorted=df.groupby(['Category','Segment'])['Profit'].sum().sort_values(ascending=False)

# %%
df_sort=df_sorted.to_frame()

# %%
sns.set(style='whitegrid')
# Define the color codes
colors = ["#E8AFF6", "#AFB0F6", "#5566B8"]

# Set the Seaborn color palette
sns.set_palette(sns.color_palette(colors))
plt.figure(figsize=(10,6))
sns.barplot(x='Category',y='Profit',hue='Segment',data=df_sort)
plt.xticks(rotation=45,ha='right')
plt.xlabel("Category",fontsize=12)
plt.ylabel("Profit",fontsize=12)
plt.title("Profit by Category And Segment",fontsize=14)
plt.tight_layout()
plt.savefig('/storage/emulated/0/pydriod3/Profit by Category.jpg',dpi=400)
plt.show()

# %%
df_region=df.groupby('Region')['Sales'].sum().sort_values(ascending=False)

# %%
df_reg=df_region.to_frame()

# %%
sns.set(style="whitegrid")
# Define the color codes
colors = ["#E8AFF6", "#AFB0F6", "#5566B8"]

# Set the Seaborn color palette
sns.set_palette(sns.color_palette(colors))
plt.figure(figsize=(10,6))
sns.barplot(x='Sales',y='Region',data=df_reg)
plt.title("Total Sales By Region")
plt.tight_layout()
plt.savefig('/storage/emulated/0/pydriod3/Total Sales By Region.jpg',dpi=400)
plt.show()

# %%
df['Order Date']=pd.to_datetime(df['Order Date'],format='mixed')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Date      51290 non-null  datetime64[ns]
#  1   Ship Date       51290 non-null  object
#  2   Ship Mode       51290 non-null  object
#  3   Customer Name   51290 non-null  object
#  4   Segment         51290 non-null  object
#  5   City            51290 non-null  object
#  6   State           51290 non-null  object
#  7   Country         51290 non-null  object
#  8   Market          51290 non-null  object
#  9   Region          51290 non-null  object
#  10  Product ID      51290 non-null  object
#  11  Category        51290 non-null  object
#  12  Sub-Category    51290 non-null  object
#  13  Product Name    51290 non-null  object
#  14  Sales           51290 non-null  float64
#  15  Quantity        51290 non-null  int64
#  16  Discount        51290 non-null  float64
# ...

# %%
df['Month']=df['Order Date'].dt.strftime('%B')

# %%
df['Year']=df['Order Date'].dt.year

# %%
df['Month']
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 51285    December
# 51286    December
# 51287    December
# 51288    December
# 51289    December
# Name: Month, Length: 51290, dtype: object

# %%
df_month=df.groupby('Month')['Sales'].sum().sort_values(ascending=False)

# %%
df_mon=df_month.to_frame()
df_mon
# Out:
#                  Sales
# Month
# December   1383335.107
# November   1377651.291
# August     1247500.805
# September  1244139.726
# June       1152367.788
# October    1120777.468
# May         976415.681
# March       951333.085
# April       851617.321
# July        838743.556
# January     775766.912
# February    722853.169

# %%
sns.set(style="whitegrid")
# Define the color codes
colors = ["#E8AFF6", "#AFB0F6", "#5566B8"]

# Set the Seaborn color palette
sns.set_palette(sns.color_palette(colors))
sns.barplot(x='Month',y='Sales',data=df_mon)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Total Sales Per Month")
plt.xticks(rotation=65)
plt.tight_layout()
plt.savefig('/storage/emulated/0/pydriod3/Total Sales Per Month.jpg',dpi=400)
plt.show()

# %%
df['Months']=df['Order Date'].dt.month

# %%
df_monthno=df.groupby('Months')['Sales'].sum().sort_values(ascending=False)

# %%
df_monno=df_monthno.to_frame()

# %%
sns.set(style="whitegrid")
# Define the color codes
colors = ["#E8AFF6", "#AFB0F6", "#5566B8"]

# Set the Seaborn color palette
sns.set_palette(sns.color_palette(colors))
plt.title("Monthly Sales Trend",fontsize=16)
sns.lineplot(x='Months',y='Sales',data=df_monno)
plt.xticks(rotation=65)
plt.tight_layout()
plt.savefig('/storage/emulated/0/pydriod3/Monthly Sales Trend.jpg',dpi=400)
plt.show()

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Month',
#        'Months'],
#       dtype='object')

# %%
total_order_by_mode=df['Ship Mode'].value_counts()

# %%
returned_Order=df[df['Profit']<0]. groupby('Ship Mode').size()

# %%
returned_Order_Percentage=(returned_Order/total_order_by_mode)*100

# %%
returned_Order_Percentage.plot(kind='bar',color=colors)
plt.xlabel("Ship Mode")
plt.ylabel("Returned Percentage")
plt.title("Returned Order Percentage Per order")
plt.tight_layout()
plt.savefig("/storage/emulated/0/pydriod3/Return.jpg",dpi=400)
plt.show()

# %%
colors=sns.color_palette('viridis')

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority', 'Month',
#        'Months'],
#       dtype='object')

# %%
df['Order Day']=df['Order Date'].dt.day_name()

# %%
order_day=df.groupby('Order Day')['Sales'].sum().sort_values(ascending=False)

# %%
sns.set(style="whitegrid")
# Define the color codes
colors = ["#E8AFF6", "#AFB0F6", "#5566B8"]

# Set the Seaborn color palette
sns.set_palette(sns.color_palette(colors))
order_day.plot(kind='bar',color=colors)
plt.xlabel("Day of The Week")
plt.ylabel("Total Sales")
plt.title("Total Sales Per Day Of The Week")
plt.tight_layout()
plt.savefig('/storage/emulated/0/pydriod3/week.jpg',dpi=400)
plt.show()
